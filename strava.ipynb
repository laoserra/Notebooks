# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tactcnt_df = pd.read_csv('./Data/2015_ride_total_tactcnt_joined.csv')

# %%
type(tactcnt_df)
# Out:
# pandas.core.frame.DataFrame

# %%
tactcnt_df.head()
# Out:
#    edge_id  tactcnt_new  tactcnt_old
# 0        1          180          169
# 1        2           20           10
# 2        3           20            3
# 3        7          165          273
# 4        8          165          272

# %%
tactcnt_df.describe()
# Out:
#              edge_id    tactcnt_new    tactcnt_old
# count  449600.000000  449600.000000  449600.000000
# mean   361649.534237     539.378081     441.549475
# std    232339.517261    1281.626084    1028.389509
# min         1.000000       5.000000       1.000000
# 25%    157627.750000      25.000000      16.000000
# 50%    337120.500000      95.000000      85.000000
# 75%    562600.750000     465.000000     405.000000
# max    807973.000000   39035.000000   28255.000000

# %%
tactcnt_df.plot.scatter(x='tactcnt_new', y='tactcnt_old', figsize=(20,10))

# %%
tactcnt_df['tactcnt_new'].corr(tactcnt_df['tactcnt_old'], method='pearson')
# Out:
# 0.9243778960955054

# %%
tactcnt_df.set_index('edge_id').plot(figsize=(20,10))
